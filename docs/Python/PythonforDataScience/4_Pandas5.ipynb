# %% [markdown]
# <head><link rel="stylesheet" href="../../../cssthemes/github.css"><meta name="viewport" content="initial-scale=1, width=device-width"></head>

# %%
import sysprint(sys.executable)from IPython.core.interactiveshell import InteractiveShellInteractiveShell.ast_node_interactivity = "all"InteractiveShell.colors = "Linux"InteractiveShell.separate_in = 0from tabulate import tabulateimport pandas as pdimport matplotlib.pyplot as pltimport os, sysos.chdir(sys.path[0]) # Change dir to the folder this .ipynb file is intags = pd.read_csv('../../../../data/w4pd/tags.csv')
# Out:
# /home/jcmint/anaconda3/envs/learningenv/bin/python

# %% [markdown]
# # Dataframe data types - strings & timestamps## String functionsStr functions don't seem to mutate the original dataframe### `df['col1'].str.split(' ')` - Splitting columns of dataframe

# %%
tags['tag'].str.split(' ').head()
# Out:
# 0      [Mark, Waters]
# 1        [dark, hero]
# 2        [dark, hero]
# 3    [noir, thriller]
# 4        [dark, hero]
# Name: tag, dtype: object

# %% [markdown]
# ### `df['col'].str.contains(' ')` - Testing for string contents

# %%
tags['isdark'] = tags['tag'].str.contains('dark')tags.head()
# Out:
#    userId  movieId            tag   timestamp isdark
# 0      18     4141    Mark Waters  1240597180  False
# 1      65      208      dark hero  1368150078   True
# 2      65      353      dark hero  1368150079   True
# 3      65      521  noir thriller  1368149983  False
# 4      65      592      dark hero  1368150078   True

# %% [markdown]
# ### `df['col1].str.replace('from', 'to')` - Replace strings with other strings

# %%
tags['light tag'] = tags['tag'].str.replace('dark', 'light').head()tags.head()
# Out:
#    userId  movieId            tag   timestamp isdark      light tag
# 0      18     4141    Mark Waters  1240597180  False    Mark Waters
# 1      65      208      dark hero  1368150078   True     light hero
# 2      65      353      dark hero  1368150079   True     light hero
# 3      65      521  noir thriller  1368149983  False  noir thriller
# 4      65      592      dark hero  1368150078   True     light hero

# %% [markdown]
# ### `df['col1'].str.extract('*')` - Match regexGet the string that matches the reg expression

# %%
tags['first tag'] = tags['tag'].str.extract('([a-zA-Z][A-Za-z])')tags.head()
# Out:
#    userId  movieId            tag   timestamp isdark      light tag first tag
# 0      18     4141    Mark Waters  1240597180  False    Mark Waters        Ma
# 1      65      208      dark hero  1368150078   True     light hero        da
# 2      65      353      dark hero  1368150079   True     light hero        da
# 3      65      521  noir thriller  1368149983  False  noir thriller        no
# 4      65      592      dark hero  1368150078   True     light hero        da

# %% [markdown]
# ### `df['col1'].str.split(' ', expand = True)` - Split str column

# %%
output = tags['light tag'].str.split(' ', expand =True)output.head()
# Out:
#        0         1
# 0   Mark    Waters
# 1  light      hero
# 2  light      hero
# 3   noir  thriller
# 4  light      hero

# %% [markdown]
# ### Cleanup

# %%
tags.drop(tags.columns[4:7], axis = 1, inplace=True)tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %% [markdown]
# ## Dealing with timestampsNeed to convert UNIX POSIX timestamp to Python format before using it.### `pd.to_datetime(df['col1'], unit = 's')` - Convert timestamp

# %%
tags['parsed time'] = pd.to_datetime(tags['timestamp'], unit='s')tags.head()
# Out:
#    userId  movieId            tag   timestamp         parsed time
# 0      18     4141    Mark Waters  1240597180 2009-04-24 18:19:40
# 1      65      208      dark hero  1368150078 2013-05-10 01:41:18
# 2      65      353      dark hero  1368150079 2013-05-10 01:41:19
# 3      65      521  noir thriller  1368149983 2013-05-10 01:39:43
# 4      65      592      dark hero  1368150078 2013-05-10 01:41:18

# %% [markdown]
# ### Using timestamp to filter

# %%
tags['After Dec 31 2013'] = tags['parsed time'] > '2013-12-31'tags.head()
# Out:
#    userId  movieId            tag   timestamp         parsed time  \
# 0      18     4141    Mark Waters  1240597180 2009-04-24 18:19:40
# 1      65      208      dark hero  1368150078 2013-05-10 01:41:18
# 2      65      353      dark hero  1368150079 2013-05-10 01:41:19
# 3      65      521  noir thriller  1368149983 2013-05-10 01:39:43
# 4      65      592      dark hero  1368150078 2013-05-10 01:41:18
#
#    After Dec 31 2013
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %% [markdown]
# ### `df.sort_values(by ='col1', ascending = False)` Sort based on time

# %%
tags = tags.sort_values(by = 'parsed time', ascending =False)tags.head()
# Out:
#         userId  movieId            tag   timestamp         parsed time  \
# 339178  102853   115149  russian mafia  1427771352 2015-03-31 03:09:12
# 158780   46072     6058    premonition  1427760764 2015-03-31 00:12:44
# 158763   46072     3409    premonition  1427760726 2015-03-31 00:12:06
# 288375   87797      215         Vienna  1427755801 2015-03-30 22:50:01
# 290535   88044   106782      profanity  1427754096 2015-03-30 22:21:36
#
#         After Dec 31 2013
# 339178               True
# 158780               True
# 158763               True
# 288375               True
# 290535               True
